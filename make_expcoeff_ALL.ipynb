# %%
import xarray as xr
import os, os.path
import glob
import sys
import scipy
import scipy.stats as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.ticker as ticker
import shapefile   
import pyproj
from shapely.geometry import LineString

from scipy.optimize import curve_fit

import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pylatex

from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature

# %%
ds1={}
ds2={}
ds3={}
ds4={}
ds5={}

ds1['CESM2_SSP585_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP585_r567_ANT27/Yearly/t2m_yearlyA_ANT27_CESM2_RACMO2.3p2_SSP585_r567_2015_2099.nc", parallel=True)  
ds2['CESM2_SSP585_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP585_r567_ANT27/Yearly/snowmelt_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP585_r567_2015_2099.nc", parallel=True)     
ds3['CESM2_SSP585_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP585_r567_ANT27/Yearly/precip_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP585_r567_2015_2099.nc", parallel=True) 
ds4['CESM2_SSP585_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP585_r567_ANT27/Yearly/snowfall_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP585_r567_2015_2099.nc", parallel=True)     
ds5['CESM2_SSP585_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP585_r567_ANT27/Yearly/subl_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP585_r567_2015_2099.nc", parallel=True)     

ds6 = xr.open_mfdataset("../../masker/Height_latlon_ANT27.nc", parallel=True)

ds1['CESM2_SSP245_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP245_r567_ANT27/Yearly/t2m_yearlyA_ANT27_CESM2_RACMO2.3p2_SSP245_r567_2011_2099.nc", parallel=True)  
ds2['CESM2_SSP245_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP245_r567_ANT27/Yearly/snowmelt_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP245_r567_2011_2099.nc", parallel=True)     
ds3['CESM2_SSP245_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP245_r567_ANT27/Yearly/precip_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP245_r567_2011_2099.nc", parallel=True)     
ds4['CESM2_SSP245_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP245_r567_ANT27/Yearly/snowfall_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP245_r567_2011_2099.nc", parallel=True)     
ds5['CESM2_SSP245_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP245_r567_ANT27/Yearly/subl_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP245_r567_2011_2099.nc", parallel=True)     

ds1['CESM2_SSP126_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP126_r567_ANT27/Yearly/t2m_yearlyA_ANT27_CESM2_RACMO2.3p2_SSP126_r567_2011_2099.nc", parallel=True)  
ds2['CESM2_SSP126_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP126_r567_ANT27/Yearly/snowmelt_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP126_r567_2011_2099.nc", parallel=True)     
ds3['CESM2_SSP126_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP126_r567_ANT27/Yearly/precip_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP126_r567_2011_2099.nc", parallel=True)     
ds4['CESM2_SSP126_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP126_r567_ANT27/Yearly/snowfall_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP126_r567_2011_2099.nc", parallel=True)     
ds5['CESM2_SSP126_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_SSP126_r567_ANT27/Yearly/subl_yearlyS_ANT27_CESM2_RACMO2.3p2_SSP126_r567_2011_2099.nc", parallel=True)     

ds1['CESM2_hist_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_hist_r567_ANT27/Yearly/t2m_yearlyA_ANT27_CESM2_RACMO2.3p2_hist_r567_1950_2014.nc", parallel=True)  
ds2['CESM2_hist_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_hist_r567_ANT27/Yearly/snowmelt_yearlyS_ANT27_CESM2_RACMO2.3p2_hist_r567_1950_2014.nc", parallel=True)     
ds3['CESM2_hist_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_hist_r567_ANT27/Yearly/precip_yearlyS_ANT27_CESM2_RACMO2.3p2_hist_r567_1950_2014.nc", parallel=True)     
ds4['CESM2_hist_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_hist_r567_ANT27/Yearly/snowfall_yearlyS_ANT27_CESM2_RACMO2.3p2_hist_r567_1950_2014.nc", parallel=True)     
ds5['CESM2_hist_r567'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_CESM2_hist_r567_ANT27/Yearly/subl_yearlyS_ANT27_CESM2_RACMO2.3p2_hist_r567_1950_2014.nc", parallel=True)     

ds1['ERA5-3H'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_ERA5-3H_ANT27/Yearly/t2m_yearlyA_ANT27_ERA5-3H_RACMO2.3p2_1979_2021.nc", parallel=True)  
ds2['ERA5-3H'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_ERA5-3H_ANT27/Yearly/snowmelt_yearlyS_ANT27_ERA5-3H_RACMO2.3p2_1979_2021.nc", parallel=True)     
ds3['ERA5-3H'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_ERA5-3H_ANT27/Yearly/precip_yearlyS_ANT27_ERA5-3H_RACMO2.3p2_1979_2021.nc", parallel=True)     
ds4['ERA5-3H'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_ERA5-3H_ANT27/Yearly/snowfall_yearlyS_ANT27_ERA5-3H_RACMO2.3p2_1979_2021.nc", parallel=True)     
ds5['ERA5-3H'] = xr.open_mfdataset("~/Dropbox/RACMO_data/RACMO2.3p2_ERA5-3H_ANT27/Yearly/subl_yearlyS_ANT27_ERA5-3H_RACMO2.3p2_1979_2021.nc", parallel=True)     


ds1['CESM2_SSP585_r567'].squeeze()
ds2['CESM2_SSP585_r567'].squeeze()
ds3['CESM2_SSP585_r567'].squeeze()
ds4['CESM2_SSP585_r567'].squeeze()
ds5['CESM2_SSP585_r567'].squeeze()

ds1['CESM2_SSP245_r567'].squeeze()
ds2['CESM2_SSP245_r567'].squeeze()
ds3['CESM2_SSP245_r567'].squeeze()
ds4['CESM2_SSP245_r567'].squeeze()
ds5['CESM2_SSP245_r567'].squeeze()

ds1['CESM2_SSP126_r567'].squeeze()
ds2['CESM2_SSP126_r567'].squeeze()
ds3['CESM2_SSP126_r567'].squeeze()
ds4['CESM2_SSP126_r567'].squeeze()
ds5['CESM2_SSP126_r567'].squeeze()

ds1['CESM2_hist_r567'].squeeze()
ds2['CESM2_hist_r567'].squeeze()
ds3['CESM2_hist_r567'].squeeze()
ds4['CESM2_hist_r567'].squeeze()
ds5['CESM2_hist_r567'].squeeze()

ds1['ERA5-3H'].squeeze()
ds2['ERA5-3H'].squeeze()
ds3['ERA5-3H'].squeeze()
ds4['ERA5-3H'].squeeze()
ds5['ERA5-3H'].squeeze()

# %%
mask2d = np.where(ds6['mask2d']>0,1,0)
lat2d = ds6.lat
lon2d = ds6.lon

# %%
modelname1 = 'ERA5-3H'
modelname2 = 'CESM2_hist_r567'
modelname3 = 'CESM2_SSP126_r567'
modelname4 = 'CESM2_SSP585_r567'
modelname5 = 'CESM2_SSP245_r567'


t2m1      = ds1[modelname1].t2m.squeeze()-273.15
snowmelt1 = ds2[modelname1].snowmelt.squeeze()#.resample(time='Y').sum()
precip1   = ds3[modelname1].precip.squeeze()#.resample(time='Y').sum()
snowfall1 = ds4[modelname1].snowfall.squeeze()
subl1     = ds5[modelname1].subl.squeeze()

rainfall1 = precip1-snowfall1
accu1     = snowfall1.values+subl1.values

t2m2      = ds1[modelname2].t2m.squeeze()-273.15
snowmelt2 = ds2[modelname2].snowmelt.squeeze()#.resample(time='Y').sum()
precip2   = ds3[modelname2].precip.squeeze()#.resample(time='Y').sum()
snowfall2 = ds4[modelname2].snowfall.squeeze()
subl2     = ds5[modelname2].subl.squeeze()

rainfall2 = precip2-snowfall2
accu2     = snowfall2+subl2

t2m3      = ds1[modelname3].t2m.squeeze()-273.15
snowmelt3 = ds2[modelname3].snowmelt.squeeze()#.resample(time='Y').sum()
precip3   = ds3[modelname3].precip.squeeze()#.resample(time='Y').sum()
snowfall3 = ds4[modelname3].snowfall.squeeze()
subl3     = ds5[modelname3].subl.squeeze()

rainfall3 = precip3-snowfall3
accu3     = snowfall3+subl3


snowmelt4 = ds2[modelname4].snowmelt.squeeze()#.resample(time='Y').sum()
precip4   = ds3[modelname4].precip.squeeze()#.resample(time='Y').sum()
t2m4      = ds1[modelname4].t2m.squeeze()-273.15
snowfall4 = ds4[modelname4].snowfall.squeeze()
rainfall4 = precip4-snowfall4
subl4     = ds5[modelname4].subl.squeeze()
accu4     = snowfall4+subl4

snowmelt5 = ds2[modelname5].snowmelt.squeeze()#.resample(time='Y').sum()
precip5   = ds3[modelname5].precip.squeeze()#.resample(time='Y').sum()
t2m5      = ds1[modelname5].t2m.squeeze()-273.15
snowfall5 = ds4[modelname5].snowfall.squeeze()
rainfall5 = precip5-snowfall5
subl5     = ds5[modelname5].subl.squeeze()
accu5     = snowfall5+subl5

#snowmelt[modelname].values = np.where(snowmelt[modelname] < 0.01,0.01,snowmelt[modelname])


snowmelt_total = np.concatenate([snowmelt1,snowmelt2,snowmelt3[4::,:,:],snowmelt4,snowmelt5[4::,:,:]])
accu_total = np.concatenate([accu1,accu2,accu3[4::,:,:],accu4,accu5[4::,:,:]])
t2m_total = np.concatenate([t2m1,t2m2,t2m3[4::,:,:],t2m4,t2m5[4::,:,:]])
rainfall_total = np.concatenate([rainfall1,rainfall2,rainfall3[4::,:,:],rainfall4,rainfall5[4::,:,:]])
#snowmelt[modelname].values = np.where(snowmelt[modelname] < 0.01,0.01,snowmelt[modelname])

# %%
print(np.shape(accu1))

# %%
subl1

# %%
def monoExp(x, A, B):
    return A*np.exp(B*x)

def monoLin(x,A,B):
    return A*x+B

def power_law(x, a, b):
    return a*np.power(x, b)

def find_intersect(x,y,y2):
    popt, pcov = curve_fit(monoExp, x, y,bounds=(0,[25000,1]) ,maxfev=10000)
    popt2, pcov = curve_fit(monoLin, x, y2,bounds=(0,[10000,10000]), maxfev=10000)
    x = np.arange(x.min()-5,5)
               
    f = monoExp(x,*popt)
    g = monoLin(x,*popt2)
    
    first_line  = LineString(np.column_stack((x, f)))
    second_line = LineString(np.column_stack((x, g)))
    MX = first_line.intersection(second_line)
    return  MX,popt,popt2

# %%
nlat = 240
mlon = 262
TT = np.zeros([nlat,mlon])
dT = np.zeros([nlat,mlon])
accu = np.zeros([nlat,mlon])
melt = np.zeros([nlat,mlon])
T2m = np.zeros([nlat,mlon])
dT_MELT = np.zeros([nlat,mlon])
dT_ACCU = np.zeros([nlat,mlon])

for i in np.arange(30,nlat):#nlat):
    for j in np.arange(20,mlon):
        print(i," ",j)
        #y = np.where(y < 0.01,0.01,y)
        y = snowmelt_total[:,i,j]

        y = np.where(y < 0.01,0.01,y) # not allowing points with too little melt

        if mask2d[i,j] == 0 or (y.any()<0) or (y.mean()<0) :
            TT[i,j] = -999
            TT[i,j] = -999           
        else:
            x = t2m_total[:,i,j]
            z = accu_total[:,i,j]
            x_ind = x.argsort()
            x = x[x_ind]
            y = y[x_ind]
            z = z[x_ind]
            xx = np.arange(x.min(),0)

            popt, pcov = curve_fit(monoExp, x,y,bounds=([0,0],[20000,1]),maxfev=10000)
                      
            x_new = x-x.min()+0.1
            z_new = z-z.min()+0.1
            xx_new = np.arange(x_new.min(),x_new.max()+10)

            popt2, pcov2 = curve_fit(f=power_law, xdata=x_new, ydata=z_new, p0=[0, 0], bounds=(-np.inf, np.inf),maxfev=10000)# Get the standard deviations of the parameters (square roots of the # diagonal of the covariance)
            xx = np.arange(x.min()-2,0)
            ff = monoExp(xx,*popt)
        
            gg = 0.7*(power_law(xx_new, *popt2)+z.min()-0.1)
    
            Aexp = popt[0]
            Bexp = popt[1]

            SE_exp = np.sqrt(np.diag(pcov))
    
            SE_Aexp = SE_exp[0]
            SE_Bexp = SE_exp[1]
      
            APL = popt2[0]
            BPL = popt2[1]
        
            SE_PL = np.sqrt(np.diag(pcov2))

            SE_APL = SE_PL[0]
            SE_BPL = SE_PL[1]
                               
            first_line = LineString(np.column_stack((xx, ff)))
           
            second_line = LineString(np.column_stack((xx_new+x.min()-0.1, gg)))

            intersection = first_line.intersection(second_line)
            # NOW COMPUTE AND INTERSECT THE LINES
          
            if intersection.geom_type == 'Point' or intersection.geom_type == 'MultiPoint':
                    
                ee1 = monoExp(xx, Aexp+SE_Aexp,Bexp+SE_Bexp) #error lines of expfit
                ee11 = monoExp(xx, Aexp-SE_Aexp,Bexp-SE_Bexp)#error lines of expfit
    
                first_lineP = LineString(np.column_stack((xx, ee1)))
                first_lineM = LineString(np.column_stack((xx, ee11)))
    
                intersectionP_melt = first_lineP.intersection(second_line) #higher error limit
                intersectionM_melt = first_lineM.intersection(second_line) #lower error limit
            
                if intersection.geom_type == 'Point':
                    MX   = intersection.x
                elif intersection.geom_type == 'MultiPoint':
                    MX   = intersection[1].x                
                    
                if intersectionP_melt.geom_type == 'Point':
                    dMXP = intersectionP_melt.x
                    DP = abs(MX-dMXP)
    
                elif intersectionP_melt.geom_type == 'MultiPoint':
                    dMXP   = intersectionP_melt[1].x
                    DP = abs(MX-dMXP)
                else:
                    DP = 0
                    
                if intersectionM_melt.geom_type == 'Point':
                    dMXM = intersectionM_melt.x
                    DM = abs(MX-dMXM)
    
                elif intersectionM_melt.geom_type == 'MultiPoint':
                    dMXP   = intersectionM_melt[1].x
                    DM = abs(MX-dMXM)
                else:
                    DM = 0  
                
                dT_MELT[i,j] = np.sqrt(DP**2+DM**2)
    
                ee2 = 0.7*(power_law(xx_new, APL+SE_APL,BPL+SE_BPL)+z.min()-0.1) #error lines of power law fit
                ee22 = 0.7*(power_law(xx_new, APL-SE_APL,BPL-SE_BPL)+z.min()-0.1)#error lines of power law fit
    
                first_line = LineString(np.column_stack((xx, ff)))
                second_lineP = LineString(np.column_stack((xx_new+x.min()-0.1, ee2)))
                second_lineM = LineString(np.column_stack((xx_new+x.min()-0.1, ee22)))
    
                intersectionP_accu = first_line.intersection(second_lineP)
                intersectionM_accu = first_line.intersection(second_lineM)
         
                if intersectionP_accu.geom_type == 'Point':
                    dMXP = intersectionP_accu.x
                    DP = abs(MX-dMXP)
    
                elif intersectionP_accu.geom_type == 'MultiPoint':
                    dMXP   = intersectionP_accu[1].x
                    DP = abs(MX-dMXP)
                else:
                    DP = 0
               
                if intersectionM_accu.geom_type == 'Point':
                    dMXM = intersectionM_accu.x
                    DM = abs(MX-dMXM)
    
                elif intersectionM_accu.geom_type == 'MultiPoint':
                    dMXM   = intersectionM_accu[1].x
                    DM = abs(MX-dMXM)
                else:
                    DM = 0   
                    
                dT_ACCU[i,j] = np.sqrt(DP**2+DM**2)
                TT[i,j] = MX #Temperature threshold
                dT[i,j]= np.sqrt(dT_ACCU[i,j]**2+dT_MELT[i,j]**2) # error in temperature threshold
                               
                
            else: 
                dT_ACCU[i,j] = 0.1*accu1[:,i,j].mean()
                dT_MELT[i,j] = 0.1*snowmelt1[:,i,j].mean()
                TT[i,j]=-999
#                TT[i,j] = t2m1[:,i,j].mean() #WHEN THRESHOLD ALREADY PASSED USE ERA5 AVERAGE
 #               dT[i,j] = 0.1*t2m1[:,i,j].mean()
                
                
                
print("WE ARE FINISHED")

# %%
os.system("rm TT_ALL.nc")
df = xr.DataArray(TT,name="TT")
df.to_netcdf('TT_ALL.nc')
os.system("rm dT_ALL.nc")

df = xr.DataArray(dT,name="dT")
df.to_netcdf('dT_ALL.nc')

# %%
dT
